# %% [markdown]
# ## Lists

# %% [markdown]
# ## Tuples

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# # Data Structure Comprehensions

# %% [markdown]
# ## List Comprehensions

# %% [markdown]
# ## Dictionary Comprehensions
